# %% [markdown]
# # Pytorch tutorial
#
# In this tutorial we will cover some basic concepts of optimization using [Pytorch](https://pytorch.org/) machine learning library.
#
# We will go through
# 1. introduction to pytorch
# 2. Example of using gradient descent on simple function
# 3. Define and train Neural Networks for classification task
#
#
# some usefully links
# 1. pytorch documentation: https://pytorch.org/docs/stable/
# 2. pytorch tutorials: https://pytorch.org/tutorials/beginner/basics/intro.html

# %% [markdown]
# # 1. Introduction to Pytorch
#
# Pytorch is one of the most famous libraries to develop deep learning models.
#
# We will go thought the basic concepts pytorch while we will explain more as we move forward on the tutorial.
#
# We will use Pytorch version: '2.1.0'

# %%
# you can install torch by using the following command
# !pip install torch==2.1.0

# %%
# you can install torchsummary by using the following command
# !pip install torchsummary

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.1.0'

# %% [markdown]
# # Tensors
#
# Tensors is one of the fundamental componentes of pytorch.
# You can think of tensors as a numpy arrays.
#
# Using Tensors pytorch is able to create computational graphs and calculate the gradients.
#
# Tensors support different kind of operations listed in the following [link](https://pytorch.org/docs/stable/torch.html#pointwise-ops)
# Apart from the pytorch operators we can apply python operators between tensors.

# %%
tensor_1 = torch.tensor([[1., 2.], 
                         [3., 3.]])

tensor_2 = torch.tensor([[1., 0], 
                         [-1., 0]])

# %%
print("tensor_1 shape: ", tensor_1.shape)
print("tensor_2 shape: ", tensor_2.shape)
# Out:
# tensor_1 shape:  torch.Size([2, 2])
# tensor_2 shape:  torch.Size([2, 2])

# %%
elem_mul = tensor_1 * tensor_2
print("Element wise multiplication")
print("Result shape: ", elem_mul.size())
elem_mul
# Out:
# Element wise multiplication
# Result shape:  torch.Size([2, 2])
# tensor([[ 1.,  0.],
#         [-3.,  0.]])

# %%
matrix_mul = torch.matmul(tensor_1,tensor_2)
print("Matrix multiplication")
print("Result shape: ", matrix_mul.size())
torch.matmul(tensor_1,tensor_2)
# Out:
# Matrix multiplication
# Result shape:  torch.Size([2, 2])
# tensor([[-1.,  0.],
#         [ 0.,  0.]])

# %%
# get tensor as numpy array
tensor_1.data.numpy()
# Out:
# array([[1., 2.],
#        [3., 3.]], dtype=float32)

# %% [markdown]
# To begin lets define a simple polynomial function.

# %%
def f(x):
    """
    A convex function
    f(x) = (x-5)^2
    """
    y = (x-5)**2
    return y

# %%
x = torch.linspace(-5, 15,100)
x
# Out:
# tensor([-5.0000, -4.7980, -4.5960, -4.3939, -4.1919, -3.9899, -3.7879, -3.5859,
#         -3.3838, -3.1818, -2.9798, -2.7778, -2.5758, -2.3737, -2.1717, -1.9697,
#         -1.7677, -1.5657, -1.3636, -1.1616, -0.9596, -0.7576, -0.5556, -0.3535,
#         -0.1515,  0.0505,  0.2525,  0.4545,  0.6566,  0.8586,  1.0606,  1.2626,
#          1.4646,  1.6667,  1.8687,  2.0707,  2.2727,  2.4747,  2.6768,  2.8788,
#          3.0808,  3.2828,  3.4848,  3.6869,  3.8889,  4.0909,  4.2929,  4.4949,
#          4.6970,  4.8990,  5.1010,  5.3030,  5.5051,  5.7071,  5.9091,  6.1111,
#          6.3131,  6.5152,  6.7172,  6.9192,  7.1212,  7.3232,  7.5253,  7.7273,
#          7.9293,  8.1313,  8.3333,  8.5354,  8.7374,  8.9394,  9.1414,  9.3434,
#          9.5455,  9.7475,  9.9495, 10.1515, 10.3535, 10.5556, 10.7576, 10.9596,
#         11.1616, 11.3636, 11.5657, 11.7677, 11.9697, 12.1717, 12.3737, 12.5758,
#         12.7778, 12.9798, 13.1818, 13.3838, 13.5859, 13.7879, 13.9899, 14.1919,
#         14.3939, 14.5960, 14.7980, 15.0000])

# %%
f(x)
# Out:
# tensor([1.0000e+02, 9.6000e+01, 9.2082e+01, 8.8246e+01, 8.4491e+01, 8.0818e+01,
#         7.7227e+01, 7.3717e+01, 7.0289e+01, 6.6942e+01, 6.3677e+01, 6.0494e+01,
#         5.7392e+01, 5.4372e+01, 5.1434e+01, 4.8577e+01, 4.5801e+01, 4.3108e+01,
#         4.0496e+01, 3.7966e+01, 3.5517e+01, 3.3150e+01, 3.0864e+01, 2.8660e+01,
#         2.6538e+01, 2.4497e+01, 2.2539e+01, 2.0661e+01, 1.8865e+01, 1.7151e+01,
#         1.5519e+01, 1.3968e+01, 1.2499e+01, 1.1111e+01, 9.8051e+00, 8.5808e+00,
#         7.4380e+00, 6.3769e+00, 5.3974e+00, 4.4995e+00, 3.6833e+00, 2.9487e+00,
#         2.2957e+00, 1.7243e+00, 1.2346e+00, 8.2645e-01, 4.9995e-01, 2.5508e-01,
#         9.1827e-02, 1.0203e-02, 1.0203e-02, 9.1827e-02, 2.5508e-01, 4.9995e-01,
#         8.2645e-01, 1.2346e+00, 1.7243e+00, 2.2957e+00, 2.9487e+00, 3.6833e+00,
#         4.4995e+00, 5.3974e+00, 6.3769e+00, 7.4380e+00, 8.5808e+00, 9.8051e+00,
#         1.1111e+01, 1.2499e+01, 1.3968e+01, 1.5519e+01, 1.7151e+01, 1.8865e+01,
#         2.0661e+01, 2.2539e+01, 2.4498e+01, 2.6538e+01, 2.8660e+01, 3.0864e+01,
#         3.3150e+01, 3.5517e+01, 3.7966e+01, 4.0496e+01, 4.3108e+01, 4.5801e+01,
#         4.8577e+01, 5.1434e+01, 5.4372e+01, 5.7392e+01, 6.0494e+01, 6.3677e+01,
#         6.6942e+01, 7.0289e+01, 7.3717e+01, 7.7227e+01, 8.0818e+01, 8.4491e+01,
#         8.8246e+01, 9.2082e+01, 9.6000e+01, 1.0000e+02])

# %%
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.legend()
plt.title("Convex function \n  f(x) = (x-5)^2")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# The above function has the following computational graph
#
# <p align="center">
#   <img style="float: left;" src="./figures/Computational_Graph.png" width="500"/>
# </p>

# %% [markdown]
# The libraries that implement automatic differentiation keep track of the different operation between variables to construct the computational graph.
#
# Having this graph allows us to compute the gradients of complex function.
#
#
# Having a computational graph we have two main operation:
# 1. **Forward pass**: calculate the output of the computational graph. In our example the value of f(x)
# 2. **Backward pass**: calculate the gradients of each node in the computational graph.
#    Having the gradients of each node allows us to calculate the final gradient of each node using the chain rule of differentiation.In our example the df/dx.
#
#
# <p align="center">
#   <img style="float: left;" src="./figures/Auto_diff_Computational_Graph.png" width="900"/>
# </p>

# %%
# create tensors with requires_grad = true in order to indicate pytorch to track the gradients of the tensor.
x = torch.tensor(5.0, requires_grad = True)
x
# Out:
# tensor(5., requires_grad=True)

# %%
# get the output of a function
y = f(x) # forward pass
y
# Out:
# tensor(0., grad_fn=<PowBackward0>)

# %%
# Compute gradients using backward function for y
y.backward()

# %%
# Access the gradients using x.grad
gradient = x.grad
print("gradient df(x)/dx|(x=5) :", gradient.data.numpy())
# Out:
# gradient df(x)/dx|(x=5) : 0.0

# %%
def grad_f(x):
    """
    return the gradient of the function evaluated at x.
    """
    grad = 2*(x-5)
    return grad

# %%
x = 5

print("f(x=5)=",f(x))
print("Analytic Gradient df/dx|(x=5)=", grad_f(5))
# Out:
# f(x=5)= 0
# Analytic Gradient df/dx|(x=5)= 0

# %% [markdown]
# # Gradient Decent
#
# **Gradient Descent (GD)** is a iterative method to find a minimum of a **convex function**.
#
# **Gradient descent** is one of the most popular algorithms to perform optimization and by far the most common way to optimize neural networks.
#
# In machine learning, Gradient descent is a way to minimize an objective function whit respect to model’s parameters by updating the parameters in the opposite direction of the gradient of the objective function w.r.t. to the parameters.
#
# <figure>
#   <img style="float: left;" src="./figures/Gradiend_descent.png" width="800"/>
# </figure>

# %% [markdown]
# ### Implement Gradient Descent
# in the following example we will find the minimum of a function using gradient decent.
#
#
# <figure>
#   <img style="float: left;" src="./figures/sgd.png" width="400"/>
# </figure>|

# %%
x_init= -13.0
thr = 0.0001
step_max = 500
lr = 0.1
min_value = 0

function = f

def gradient_decent(function, x_init, min_value, lr, step_max, thr):
    x = torch.tensor(x_init, requires_grad = True)
    
    x_history = [x.data]
    step = 0 
    while step < step_max:
        # step 1. Forward pass to get the output
        y = function(x)

        # step 2. Backward pass to calculate the gradient
        y.backward()

        # step 3. Update x to find minimum
        gradient = x.grad.data
        x.data = x.data - lr * gradient
        x.grad.data.zero_() # tenchical steps, otherwise accumulate the gradients

        # just keep the values of x
        x_history += [x.data]
        step = step +1
        
        # stoping critiria
        if abs(function(x.data) - function(x_history[-2])) < thr:
            break
    x_history = np.array(x_history)
    return x.data, step, x_history

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.1,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 24
# Minimum: 4.962221

# %%
x_history = np.array(x_history)

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 0.005

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.005,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 100
# Minimum: 2.071741

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 0.7

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 0.7,
                                                step_max = 100,
                                                thr = 0.001)

# %%
print("Total steps to achive minimum:" , total_steps)
print("Minimum:" , x_min.data.numpy())
# Out:
# Total steps to achive minimum: 7
# Minimum: 5.0131073

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# ### lr = 1.1

# %%
x_min, total_steps, x_history = gradient_decent(function = f, 
                                                x_init = -3.0 ,
                                                min_value=0,
                                                lr = 1.1,
                                                step_max = 5,
                                                thr = 0.001)

# %%
x = np.linspace(-13, 23,100)
# x_history = np.array()
plt.figure()
plt.plot(x, f(x), label = "(x-5)^2")
plt.plot(x_history, f(x_history),marker = "o", color="r")
plt.legend()
plt.title("Convex function")
plt.ylabel("y")
plt.xlabel("x")
plt.show()
plt.close()

# %% [markdown]
# # Load Adult dataset

# %%
from collections import OrderedDict

data_types = OrderedDict([
    ("age", "int"),
    ("workclass", "category"),
    ("final_weight", "int"),  # originally it was called fnlwgt
    ("education", "category"),
    ("education_num", "int"),
    ("marital_status", "category"),
    ("occupation", "category"),
    ("relationship", "category"),
    ("race", "category"),
    ("sex", "category"),
    ("capital_gain", "float"),  # required because of NaN values
    ("capital_loss", "int"),
    ("hours_per_week", "int"),
    ("native_country", "category"),
    ("income_class", "category"),
])
target_column = "income_class"

# %%
def read_dataset(path):
    return pd.read_csv(
        path,
        names=data_types,
        index_col=None,

        comment='|',  # test dataset has comment in it
        skipinitialspace=True,  # Skip spaces after delimiter
        na_values={
            'capital_gain': 99999,
            'workclass': '?',
            'native_country': '?',
            'occupation': '?',
        },
        dtype=data_types,
    )

def clean_dataset(data):
    # Test dataset has dot at the end, we remove it in order
    # to unify names between training and test datasets.
    data['income_class'] = data.income_class.str.rstrip('.').astype('category')

    # Remove final weight column since there is no use
    # for it during the classification.
    data = data.drop('final_weight', axis=1)

    # Duplicates might create biases during the analysis and
    # during prediction stage they might give over-optimistic
    # (or pessimistic) results.
    data = data.drop_duplicates()

    # Binary target variable (>50K == 1 and <=50K == 0)
    data[target_column] = (data[target_column] == '>50K').astype(int)

    # Categorical dataset
    categorical_features = data.select_dtypes('category').columns
    data[categorical_features] = data.select_dtypes('category').apply(lambda x: x.cat.codes)
    return data

# %%
import pandas as pd
# get and clean train dataset
TRAIN_DATA_FILE = 'http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
train_data = clean_dataset(read_dataset(TRAIN_DATA_FILE))
train_data = train_data.dropna()
print("Train dataset shape:", train_data.shape)

# get and clean test dataset
TEST_DATA_FILE = 'http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test'
test_data = clean_dataset(read_dataset(TEST_DATA_FILE))
test_data = test_data.dropna()
print("Test dataset shape:", test_data.shape)
# Out:
# Train dataset shape: (28938, 14)
# Test dataset shape: (15175, 14)

# %%
target_column = "income_class"
features = train_data.columns.difference([target_column])
sensitive_feature = ["sex"]
non_sensitive_features = list(set(features).difference(set(sensitive_feature)))

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(train_data[features], train_data[[target_column]], test_size=0.1)
X_test, y_test = test_data[features], test_data[[target_column]]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train),columns = features)
X_val = pd.DataFrame(scaler.transform(X_val),columns = features)
X_test = pd.DataFrame(scaler.transform(X_test),columns = features)

# %%
X_train.shape, X_val.shape, X_test.shape
# Out:
# ((26044, 13), (2894, 13), (15175, 13))

# %% [markdown]
# # Neural Networks
#
# Neural Networks are powerful function approximator that archives state-of-the-art performance on a lot of application the last decade on machine learning.
#
# The performance of the Deep Neural Network's is due to their high number of parameters and the efficient learning methods used to train those networks.
# For example the gtp-3 languages model was about by 175 billion parameters.
#
# Neural Networks, adjust their parameters (training), using the gradient descent method to **minimise a loss function** $L$.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/neural_net_new.png" width="800"/>
# </figure>|

# %% [markdown]
# ### Operation of each node

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/neuron_2.png" width="600"/>
# </figure>

# %% [markdown]
# # Activation Functions
#
# Activation functions play an integral role in neural networks by introducing non-linearity.
# This non-linearity allows neural networks to develop complex representations and functions based on the inputs that would not be possible with a simple linear layers.
#
# Bellow we illustrate some of the most famous activation functions

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/acitvation_fun.png" width="600"/>
# </figure>

# %% [markdown]
# # Classification problem
#
# In classification problem the output of the neural network can be probability of each class p(y|x).
#
# So for binary classification we can do that using a single output to indicate the p(y=1|x).
# This has to be bounded between [0,1] in order to be a probability.
# To do so we can use the sigmoid function that we can illustrate bellow.
#
# <figure>
#   <img style="float: left;" src="./figures/sigmoid.png" width="400"/>
# </figure>

# %% [markdown]
# Then we can use the binary cross entropy loss as the **loss function**
#
# <figure>
#   <img style="float: left;" src="./figures/binary_ce.png" width="400"/>
# </figure>

# %% [markdown]
# Where
# $$\hat{Y} = f(x) = p(y=1|x)$$

# %% [markdown]
# As a note, for regression problem we don't use activation function in the final layer, while loss function is usually the mean square error.

# %% [markdown]
# # Define Neural Network with pytorch
#
# We will implement a simple neural network for classification problem with pytorch.
# The following network has 2 hidden layers following by an output layer.

# %%
class NeuralNetwork(torch.nn.Module):
    """
    Simple two layer neural network for regression
    """
    def __init__(self, num_input_features: int, layer1_units: int = 200, layer2_units: int = 100):
        super().__init__()
        
        # layer 1
        layer_1_units = layer1_units
        self.layer_1 = torch.nn.Linear(in_features=num_input_features,
                                       out_features=layer_1_units)
        self.activation_1 = torch.nn.ReLU()
        
        # layer  2
        layer_2_units = layer2_units
        self.layer_2 = torch.nn.Linear(in_features=layer_1_units,
                                       out_features=layer_2_units)
        self.activation_2 = torch.nn.ReLU()
        
        # layer output layer
        self.out_layer = torch.nn.Linear(in_features=layer_2_units,
                                         out_features=1)
        self.out_activation= torch.nn.Sigmoid()

    def forward(self, x):
        x_1 = self.activation_1( self.layer_1( x ) )
        x_2 = self.activation_2( self.layer_2( x_1 ) )
        output = self.out_activation(self.out_layer(x_2))
        return output

# %%
from torchsummary import summary
model = NeuralNetwork(num_input_features=12)
summary(model, input_size= [[12]])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 200]           2,600
#               ReLU-2                  [-1, 200]               0
#             Linear-3                  [-1, 100]          20,100
#               ReLU-4                  [-1, 100]               0
#             Linear-5                    [-1, 1]             101
#            Sigmoid-6                    [-1, 1]               0
# ================================================================
# Total params: 22,801
# Trainable params: 22,801
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.09
# ----------------------------------------------------------------

# %% [markdown]
# ### make predictions

# %%
x = torch.rand((100,12))
y = torch.randint(0, 1, (100,1))
                  
predicted_proba = model.forward(x)

# %%
predicted_proba.shape # p(y=1|x)
# Out:
# torch.Size([100, 1])

# %%
predicted_proba
# Out:
# tensor([[0.4496],
#         [0.4537],
#         [0.4671],
#         [0.4701],
#         [0.4514],
#         [0.4576],
#         [0.4571],
#         [0.4624],
#         [0.4505],
#         [0.4679],
#         [0.4819],
#         [0.4410],
#         [0.4601],
#         [0.4517],
#         [0.4586],
#         [0.4692],
#         [0.4579],
#         [0.4507],
#         [0.4505],
#         [0.4669],
#         [0.4595],
#         [0.4535],
#         [0.4470],
#         [0.4665],
#         [0.4565],
#         [0.4488],
#         [0.4687],
#         [0.4617],
#         [0.4571],
#         [0.4542],
#         [0.4593],
#         [0.4500],
#         [0.4585],
#         [0.4593],
#         [0.4556],
#         [0.4537],
#         [0.4603],
#         [0.4448],
#         [0.4509],
#         [0.4647],
#         [0.4560],
#         [0.4596],
#         [0.4693],
#         [0.4638],
#         [0.4685],
#         [0.4511],
#         [0.4630],
#         [0.4663],
#         [0.4475],
#         [0.4599],
#         [0.4635],
#         [0.4561],
#         [0.4497],
#         [0.4543],
#         [0.4562],
#         [0.4595],
#         [0.4654],
#         [0.4717],
#         [0.4655],
#         [0.4515],
#         [0.4580],
#         [0.4598],
#         [0.4665],
#         [0.4577],
#         [0.4542],
#         [0.4669],
#         [0.4536],
#         [0.4473],
#         [0.4537],
#         [0.4711],
#         [0.4582],
#         [0.4668],
#         [0.4632],
#         [0.4632],
#         [0.4638],
#         [0.4582],
#         [0.4705],
#         [0.4463],
#         [0.4660],
#         [0.4506],
#         [0.4656],
#         [0.4568],
#         [0.4556],
#         [0.4661],
#         [0.4605],
#         [0.4523],
#         [0.4612],
#         [0.4571],
#         [0.4701],
#         [0.4535],
#         [0.4551],
#         [0.4656],
#         [0.4539],
#         [0.4610],
#         [0.4560],
#         [0.4575],
#         [0.4598],
#         [0.4643],
#         [0.4619],
#         [0.4591]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# ### optimise network
# perfom a single iteration of sgd.

# %%
model = NeuralNetwork(num_input_features=12)

# to make the optimization pytorch has different optimizers. 
lr = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss()

# %%
model.layer_2.weight
# Out:
# Parameter containing:
# tensor([[ 0.0525,  0.0480,  0.0551,  ..., -0.0453, -0.0225, -0.0514],
#         [ 0.0289, -0.0518, -0.0488,  ..., -0.0593, -0.0700, -0.0012],
#         [ 0.0682, -0.0437, -0.0521,  ...,  0.0612, -0.0178,  0.0327],
#         ...,
#         [-0.0542,  0.0288, -0.0373,  ...,  0.0439,  0.0173,  0.0422],
#         [-0.0454, -0.0556,  0.0619,  ..., -0.0354,  0.0284, -0.0531],
#         [ 0.0668, -0.0688, -0.0630,  ...,  0.0554,  0.0036, -0.0466]],
#        requires_grad=True)

# %%
x = torch.rand((100, 12))
y = torch.randint(0, 1, (100, 1), dtype = torch.float)
                  
predicted_proba = model.forward(x)
loss = loss_fn(predicted_proba, y)
                  
loss.backward()
optimizer.step() # the optimiser aply the gradients to change the weights.

optimizer.zero_grad() # reset the gradients

# %%
model.layer_2.weight
# Out:
# Parameter containing:
# tensor([[ 0.0525,  0.0480,  0.0551,  ..., -0.0453, -0.0225, -0.0514],
#         [ 0.0289, -0.0518, -0.0488,  ..., -0.0593, -0.0700, -0.0012],
#         [ 0.0682, -0.0437, -0.0521,  ...,  0.0612, -0.0178,  0.0327],
#         ...,
#         [-0.0542,  0.0288, -0.0373,  ...,  0.0439,  0.0173,  0.0422],
#         [-0.0454, -0.0556,  0.0619,  ..., -0.0354,  0.0284, -0.0531],
#         [ 0.0668, -0.0688, -0.0630,  ...,  0.0553,  0.0036, -0.0466]],
#        requires_grad=True)

# %% [markdown]
# # Batching data
#
# When we train neural network we usually train our model using batches of training example.
#
#
# <figure>
#   <img style="float: left;" src="./figures/batches.png" width="500"/>
# </figure>
#
#
#
# Batching method is performed for different reasons.
# First of all in we have a huge dataset we cannot fit all the data in our memery.
# Moreover, using batches requires less time to fit the model as in the same time you can perform more update in the weights of the model. One drawback of using batches is that we approximate the gradient directions, so having very small batch size can affect the coverage of your model.
#
# So batch size is an additional hyperparameter of our training algorithm.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/train_loop.png" width="500"/>
# </figure>

# %% [markdown]
# lets use pytorch to batch our data.
#
# In summary PyTorch provides two main data classes: **DataLoader** and **Dataset** to handle your data.
#
# **Dataset**  stores the samples and their corresponding labels, and **DataLoader** wraps an iterable around the Dataset to enable easy access to the batches.
#
# you can read more at: https://pytorch.org/tutorials/beginner/basics/data_tutorial.html

# %%
# covert data into tensors
train_x_tensor = torch.tensor(X_train.values, dtype=torch.float)
train_y_tensor = torch.tensor(y_train.values, dtype=torch.float)

# use the dataset class wrapper for tensors
train_tensor_dataset = torch.utils.data.TensorDataset(train_x_tensor, train_y_tensor)# there are more coplex dataset
                                                                                     # i.e images or text data

# pass the dataset class into Dataloader to batch and shuffle your data
train_dataloader = torch.utils.data.DataLoader(train_tensor_dataset,
                                               batch_size=64,
                                               shuffle=True)

# %%
for batch in enumerate(train_dataloader):
    batch_x, batch_y = next(iter(train_dataloader)) # get next iteam
batch_x.shape
# Out:
# torch.Size([64, 13])

# %%
batch_x
# Out:
# tensor([[-0.3081, -0.2441, -0.2303,  0.2061, -0.4132, -0.2032,  1.5609,  0.3097,
#          -1.3368,  0.4160,  1.5497, -1.3934, -1.2564],
#         [ 0.2764, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458,  1.5609,  0.3097,
#           0.7894,  0.4160,  1.5497, -1.3934,  0.0812],
#         [-0.7464, -0.2441, -0.2303,  0.2061, -0.4132, -0.2032,  0.9114,  0.3097,
#           1.2619,  0.4160,  1.5497,  0.7177,  0.0812],
#         [ 0.4955, -0.2441, -0.2303, -0.3038,  1.1023, -0.0458, -0.3877,  0.3097,
#           0.7894,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-0.8194, -0.2441, -0.2303, -2.5983, -1.5499, -2.0134,  0.9114,  0.3097,
#           0.3169,  0.4160,  1.5497, -1.3934,  0.0812],
#         [-1.4038, -0.2441, -0.2303,  1.2258, -0.0344, -2.0134,  0.9114,  0.3097,
#           0.3169,  0.4160,  0.9348, -1.3934,  0.0812],
#         [ 1.2260, -0.2441, -0.2303,  0.2061, -0.4132, -0.0458, -0.3877,  0.3097,
#          -0.8643,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 0.4955, -0.2441, -0.2303,  0.2061, -0.4132, -0.0458, -0.3877,  0.3097,
#           1.2619,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-0.1620, -0.2441, -0.2303,  0.2061, -0.4132,  1.2135, -1.6868,  0.3097,
#          -0.3918,  0.4160,  1.5497,  0.7177,  1.4187],
#         [-1.3308,  0.5668, -0.2303,  0.2061, -0.4132, -0.0458,  0.9114,  0.3097,
#           0.0807,  0.4160,  0.9348,  0.7177,  0.0812],
#         [ 1.2260, -0.2441, -0.2303, -0.3038,  1.1023, -0.0458, -0.3877,  0.3097,
#          -0.6280,  0.4160, -0.9099,  0.7177,  2.0875],
#         [ 0.2033, -0.2441, -0.2303,  1.2258, -0.0344,  0.3477, -0.3877,  0.3097,
#           0.7894,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 0.2033, -0.2441, -0.2303,  0.2061, -0.4132, -0.4393,  0.9114, -4.4259,
#          -1.3368, -1.8425,  1.5497, -1.3934,  0.0812],
#         [ 0.7147, -0.2441, -0.2303,  0.4610,  1.4812,  0.7413, -0.3877,  0.3097,
#          -0.6280,  0.4160, -0.9099,  0.7177, -1.2564],
#         [-0.6733, -0.2441, -0.2303,  0.2061, -0.4132, -0.0458,  0.9114,  0.3097,
#           1.2619,  0.4160,  0.3199,  0.7177,  0.0812],
#         [ 0.7877, -0.2441, -0.2303, -0.0489,  2.2389, -0.0458, -0.3877,  0.3097,
#           0.7894,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 1.2991, -0.2441, -0.2303, -0.3038,  1.1023, -0.0458, -0.3877, -0.7831,
#          -0.6280, -2.9718, -0.9099,  0.7177,  0.0812],
#         [ 0.1303, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458, -0.3877,  0.3097,
#          -0.6280, -1.8425, -0.9099,  0.7177, -1.9251],
#         [-0.0889, -0.2441, -0.2303, -0.3038,  1.1023, -0.4393, -0.3877, -1.2688,
#           0.3169,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-1.6230,  0.1490, -0.2303, -1.0686, -1.9288, -1.3050,  0.9114,  0.3097,
#           0.3169,  0.4160,  0.9348,  0.7177,  0.0812],
#         [ 0.5686,  1.6856, -0.2303,  0.2061, -0.4132, -0.0458, -0.3877,  0.3097,
#          -0.8643,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-0.6733, -0.2441, -0.2303,  1.2258, -0.0344,  0.3477,  0.9114,  0.3097,
#          -0.8643,  0.4160, -0.2950,  0.7177,  1.4187],
#         [ 0.5686, -0.2441, -0.2303,  0.4610,  1.4812,  0.7413, -0.3877,  0.3097,
#          -0.6280,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-0.8194, -0.2441,  4.2296,  1.2258, -0.0344,  1.1348, -0.3877,  0.3097,
#           1.2619,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-0.4542, -0.2441, -0.2303,  1.2258, -0.0344, -0.4393,  0.9114,  0.3097,
#           1.2619, -1.8425, -0.2950,  0.7177,  0.0812],
#         [-0.4542, -0.2441, -0.2303,  0.7159, -3.4443, -0.0458, -0.3877, -1.2688,
#          -0.3918,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 0.1303,  1.3904, -0.2303, -0.3038,  1.1023,  0.7413, -0.3877,  0.3097,
#          -0.6280,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 0.5686,  0.8310, -0.2303, -0.3038,  1.1023,  1.9218, -0.3877, -1.5117,
#          -0.6280, -2.9718, -0.9099,  0.7177,  0.0812],
#         [-0.0889, -0.2441, -0.2303,  1.2258, -0.0344, -1.6199, -1.6868,  0.3097,
#          -1.3368, -1.8425,  1.5497, -1.3934,  0.0812],
#         [-0.9655, -0.2441, -0.2303, -0.3038,  1.1023,  0.3477,  0.9114,  0.3097,
#           0.7894,  0.4160, -0.2950, -1.3934,  0.0812],
#         [ 0.3494, -0.2441, -0.2303, -0.3038,  1.1023,  1.5283, -0.3877,  0.3097,
#           0.7894,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 0.3494, -0.2441, -0.2303,  0.2061, -0.4132,  1.5283,  0.9114,  0.3097,
#          -0.8643, -1.8425, -0.2950,  0.7177,  0.0812],
#         [-0.4542, -0.2441, -0.2303,  1.2258, -0.0344, -0.4393,  0.9114,  0.3097,
#          -1.3368, -2.9718,  1.5497, -1.3934,  0.0812],
#         [-1.1116, -0.2441, -0.2303,  0.2061, -0.4132, -0.0458,  0.9114,  0.3097,
#           1.4981,  0.4160, -0.2950, -1.3934, -1.2564],
#         [-0.7464, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458,  0.9114,  0.3097,
#           1.4981,  0.4160, -0.2950, -1.3934,  0.0812],
#         [-0.5272, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458,  0.9114, -4.4259,
#           0.3169, -2.9718,  0.3199,  0.7177,  0.0812],
#         [ 1.1530, -0.2441, -0.2303, -1.0686, -1.9288, -0.0458, -0.3877,  0.3097,
#          -0.3918,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 2.0296, -0.2441, -0.2303,  0.2061, -0.4132,  1.5283, -0.3877,  0.3097,
#          -0.3918,  0.4160, -0.9099,  0.7177,  1.4187],
#         [ 0.8608, -0.2441,  4.2296,  1.2258, -0.0344,  0.7413, -0.3877,  0.3097,
#           1.2619,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 0.7877, -0.2441, -0.2303, -1.5785, -2.6866, -0.0458, -0.3877, -1.2688,
#          -0.1556,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-1.1847, -0.2441, -0.2303,  1.2258, -0.0344, -0.4393,  0.9114,  0.3097,
#          -0.3918,  0.4160,  0.9348,  0.7177,  1.4187],
#         [ 0.4225, -0.2441, -0.2303,  0.2061, -0.4132,  0.3477, -0.3877,  0.3097,
#          -0.6280,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-0.3081,  1.4888, -0.2303,  0.2061, -0.4132,  0.7413,  0.9114,  0.3097,
#          -0.6280,  0.4160, -0.2950,  0.7177,  1.4187],
#         [-0.8925, -0.2441, -0.2303,  0.2061, -0.4132, -0.0458, -0.3877,  0.3097,
#           0.3169,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 0.5686, -0.2441, -0.2303,  0.2061, -0.4132, -0.0458, -1.6868,  0.3097,
#          -1.3368, -2.9718,  1.5497, -1.3934,  2.0875],
#         [-1.4038, -0.2441, -0.2303,  1.2258, -0.0344, -1.6199,  0.9114,  0.3097,
#           0.3169,  0.4160, -0.2950, -1.3934,  0.0812],
#         [-0.9655, -0.2441, -0.2303, -2.3433, -1.1710, -0.0458,  0.9114,  0.3097,
#           0.3169,  0.4160, -0.2950,  0.7177,  0.0812],
#         [-0.4542, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458, -0.3877,  0.3097,
#          -1.3368, -1.8425, -0.9099,  0.7177,  0.0812],
#         [-1.4769, -0.2441, -0.2303, -0.3038,  1.1023, -0.0458,  0.9114, -1.6331,
#          -1.5730, -1.8425,  0.9348, -1.3934, -2.5939],
#         [ 0.2764, -0.2441, -0.2303,  0.2061, -0.4132,  0.3477, -0.3877,  0.3097,
#          -0.8643,  0.4160, -0.9099,  0.7177,  0.0812],
#         [ 0.4225, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458,  0.9114,  0.3097,
#           0.3169,  0.4160, -0.2950,  0.7177,  0.0812],
#         [ 1.5182, -0.2441, -0.2303, -0.8137,  0.7234, -0.0458, -0.3877,  0.3097,
#           0.3169, -1.8425, -0.9099,  0.7177, -1.9251],
#         [-1.2577, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458,  0.9114,  0.3097,
#          -1.3368,  0.4160,  1.5497, -1.3934,  0.0812],
#         [ 0.2033, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458, -0.3877,  0.3097,
#           1.4981,  0.4160,  2.1646, -1.3934,  0.0812],
#         [ 0.4955, -0.2441, -0.2303,  0.2061, -0.4132,  0.5839,  0.9114,  0.3097,
#          -0.8643,  0.4160, -0.2950, -1.3934,  0.0812],
#         [-0.4542, -0.2441, -0.2303, -0.5588,  0.3445,  0.3477,  1.5609,  0.3097,
#           0.7894,  0.4160, -0.2950,  0.7177,  0.0812],
#         [-0.0889, -0.2441, -0.2303, -0.3038,  1.1023, -0.2819, -0.3877,  0.3097,
#          -0.6280,  0.4160, -0.9099,  0.7177,  2.0875],
#         [ 0.2033, -0.2441, -0.2303, -0.3038,  1.1023, -0.0458, -0.3877,  0.3097,
#           0.7894,  0.4160, -0.9099,  0.7177, -1.9251],
#         [-0.5272, -0.2441, -0.2303,  1.2258, -0.0344, -0.0458, -1.6868,  0.3097,
#          -1.5730,  0.4160, -0.2950,  0.7177, -2.5939],
#         [-1.4038, -0.2441, -0.2303, -1.0686, -1.9288, -0.0458,  0.9114,  0.3097,
#           0.0807,  0.4160,  0.9348,  0.7177,  0.0812],
#         [-0.5272, -0.2441, -0.2303,  0.2061, -0.4132, -2.1708,  0.9114,  0.3097,
#           0.3169, -1.8425,  1.5497, -1.3934,  0.0812],
#         [-0.8194, -0.2441, -0.2303,  0.2061, -0.4132,  0.7413,  0.9114,  0.3097,
#          -0.6280,  0.4160, -0.2950, -1.3934,  0.0812],
#         [ 1.2260, -0.2441, -0.2303, -0.3038,  1.1023, -0.8328, -0.3877, -4.1830,
#          -1.3368,  0.4160, -0.9099,  0.7177,  0.0812],
#         [-0.6003, -0.2441, -0.2303, -0.8137,  0.7234, -2.9578,  0.9114,  0.3097,
#           0.7894,  0.4160,  0.9348,  0.7177,  0.0812]])

# %%
# convert val data to tensor for later
val_x_tensor = torch.tensor(X_val.values, dtype=torch.float)
val_y_tensor = torch.tensor(y_val.values, dtype=torch.float)

# %% [markdown]
# # Define training loop

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/train_loop.png" width="400"/>
# </figure>

# %%
def training_step(model, input_data, optimizer, loss_fn):
    # reset gradients of the optimizer
    optimizer.zero_grad()
    
    # unfold data
    x_batch, y_batch = input_data
    
    # get predictions
    y_pred_propa = model(x_batch)
    
    # calculate loss
    loss = loss_fn(y_pred_propa, y_batch)

    # compute gradients 
    loss.backward()
    
    # optimise network
    optimizer.step()
    
    # compute metrics for monitoring
    with torch.no_grad(): 
        y_pred = (y_pred_propa>0.5) * 1
        train_acc = torch.sum(y_pred == y_batch) / y_batch.shape[0]

    return loss.data.numpy(), train_acc.data.numpy()

# %%
def evaluation_step(model, input_data, loss_fn):
    # when we use torch.no_grad pytorch didnt store information
    # that is required to calculate gradients so is fasterr 
    with torch.no_grad(): 
        x_batch, y_batch = input_data
        y_pred_proba = model(x_batch)
        loss = loss_fn(y_pred_proba, y_batch)

        # compute metrics
        y_pred = (y_pred_proba>0.5) * 1
        acc = torch.sum(y_pred == y_batch) / y_batch.shape[0]
    return loss.data.numpy(), acc.data.numpy()

# %%
model = NeuralNetwork(num_input_features=13)

lr = 0.02
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss() # binary cross entropy

# %%
# parameters of the training loop
epochs = 200

# %%
# -------------------- Train  Loop----------------------------
def train(
    model: torch.nn.Module,
    epochs: int,
    train_dataloader: torch.utils.data.DataLoader,
    optimizer: torch.optim.Optimizer,
    loss_fn: torch.nn.Module,
    val_data: tuple,
):
    train_history = []
    val_history = []

    for epoch in range(epochs):  # iterate over epoch
        # -------------------- 1. Training on each epoch ----------------------------
        accumulated_loss, accumulated_accuracy = (
            0,
            0,
        )  # monitor loss and metrics during training
        for step, batch_data in enumerate(train_dataloader):  # iterate over batch
            loss, accuracy = training_step(
                model, batch_data, optimizer, loss_fn
            )  # train model using a single batch
            accumulated_loss = (step * accumulated_loss + loss) / (step + 1)
            accumulated_accuracy = (step * accumulated_accuracy + accuracy) / (step + 1)

        # store the loss and the metrics at the end of each epoch
        train_history += [
            {"loss": accumulated_loss, "accuracy": accumulated_accuracy, "epoch": epoch}
        ]

        # -------------------- 2. Monitor Error on Validation set ----------------------------
        val_loss, val_accuracy = evaluation_step(model, val_data, loss_fn)
        val_history += [{"loss": val_loss, "accuracy": val_accuracy, "epoch": epoch}]
        if epoch % 10 == 0:
            print(
                f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy-:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}"
            )

    return pd.DataFrame(val_history), pd.DataFrame(train_history)

# %%
val_history_df_big, train_history_df_big = train(model, epochs, train_dataloader, optimizer, loss_fn, (val_x_tensor, val_y_tensor))
# Out:
# Epoch 0/200:  loss:0.483, accuracy-:0.775, val_loss:0.388, val_accuracy->0.833
# Epoch 10/200:  loss:0.333, accuracy-:0.842, val_loss:0.323, val_accuracy->0.850
# Epoch 20/200:  loss:0.326, accuracy-:0.845, val_loss:0.319, val_accuracy->0.853
# Epoch 30/200:  loss:0.325, accuracy-:0.847, val_loss:0.320, val_accuracy->0.852
# Epoch 40/200:  loss:0.321, accuracy-:0.848, val_loss:0.317, val_accuracy->0.852
# Epoch 50/200:  loss:0.317, accuracy-:0.849, val_loss:0.317, val_accuracy->0.855
# Epoch 60/200:  loss:0.314, accuracy-:0.852, val_loss:0.318, val_accuracy->0.850
# Epoch 70/200:  loss:0.311, accuracy-:0.852, val_loss:0.347, val_accuracy->0.853
# Epoch 80/200:  loss:0.308, accuracy-:0.852, val_loss:0.349, val_accuracy->0.854
# Epoch 90/200:  loss:0.305, accuracy-:0.854, val_loss:0.350, val_accuracy->0.850
# Epoch 100/200:  loss:0.303, accuracy-:0.856, val_loss:0.323, val_accuracy->0.851
# Epoch 110/200:  loss:0.300, accuracy-:0.857, val_loss:0.347, val_accuracy->0.856
# Epoch 120/200:  loss:0.298, accuracy-:0.858, val_loss:0.353, val_accuracy->0.850
# Epoch 130/200:  loss:0.295, accuracy-:0.859, val_loss:0.355, val_accuracy->0.846
# Epoch 140/200:  loss:0.293, accuracy-:0.860, val_loss:0.351, val_accuracy->0.850
# Epoch 150/200:  loss:0.291, accuracy-:0.860, val_loss:0.357, val_accuracy->0.850
# Epoch 160/200:  loss:0.289, accuracy-:0.863, val_loss:0.353, val_accuracy->0.853
# Epoch 170/200:  loss:0.287, accuracy-:0.864, val_loss:0.357, val_accuracy->0.851
# Epoch 180/200:  loss:0.285, accuracy-:0.864, val_loss:0.359, val_accuracy->0.848
# Epoch 190/200:  loss:0.282, accuracy-:0.865, val_loss:0.363, val_accuracy->0.844

# %% [markdown]
# # Learning Curves and Overfitting
#
# **Overfitting** refers to the phenomenon when our model performs well on the training set but exhibits poor performance on the testing set.
#
# Since neural networks have a large number of parameters, they are prone to overfitting the training data, resulting in bad performance during testing.
# This occurs when the model exploits pattern between the data (X) and the labels (Y) that is not in the testing data.
#
# One way to monitor the performance of our algorithm is by using learning curves.
#
# Learning curves track the performance of the model during training by measuring various metrics at regular optimization steps.
# Learning curves provide valuable insights into the model's behavior, allowing us to detect overfitting.
#
#
# To identify overfitting, we typically compare the learning curves of the training and validation sets.

# %% [markdown]
# <figure>
#   <img style="float: left;" src="./figures/epoch-error-curve-fitting.png" width="400"/>
# </figure>

# %% [markdown]
# For example, in the plot above, we can observe the learning curves of the training and validation sets during training. At the beginning of training, the model minimizes the loss on both the training and validation sets. However, after several epochs, you can see that the validation error starts to increase while the training loss continues to decrease. This indicates that the model is learning patterns specific to the training set that do not generalize well to the validation set, leading to loss increases.

# %%
def plot_learning_curve(
        train_history_df: pd.DataFrame,
        val_history_df: pd.DataFrame,
        sub_task: str = "None",
        epochs: int = None,
        key: str = "accuracy",
):
    plt.figure()
    plt.plot(train_history_df["epoch"],train_history_df[key], label = "Training set")
    plt.plot(val_history_df["epoch"],val_history_df[key], label = "Validation set")
    plt.title(f"Learning Curve - {sub_task} - {epochs} epochs")
    plt.ylabel("Cross Entropy Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def plot_loss(train_history_df: pd.DataFrame, val_history_df: pd.DataFrame, epochs: int = None):
    plot_learning_curve(train_history_df, val_history_df, "Loss", epochs, "loss")

# %%
def plot_accuracy(train_history_df: pd.DataFrame, val_history_df: pd.DataFrame, epochs: int = None):
    plot_learning_curve(train_history_df, val_history_df, "Accuracy", epochs, "accuracy")

# %%
plot_loss(train_history_df_big, val_history_df_big, epochs)
plot_accuracy(train_history_df_big, val_history_df_big, epochs)

# %% [markdown]
# # Assigment 6
#
# In the 6th assigment we will see the effect of different techniques to reduce overfiting when training a neural network.

# %% [markdown]
# # A. Early stopping
# Early stopping is an optimization technique used to reduce overfitting without compromising on model accuracy. The main idea behind early stopping is to stop training before a model starts to over-fit.
#
#
# To use early stopping, you watch for the validation loss. If it stops improving for several consecutive epochs , indicated by the "patient" parameter, you stop training.
#
# **Steps:**
#    1) Implement Early Stopping.
#    2) Train your model using early stopping.
#    3) Check different patient parameters. For example, you can set patient = {5 , 100}. Can the patient parameter affect the coverage of your network?

# %% [markdown]
# # Solution

# %%
model = NeuralNetwork(num_input_features=13)

epochs = 400
lr = 0.02
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss() # binary cross entropy

# %%
def train_with_early_stopping(
    model: torch.nn.Module,
    epochs: int,
    train_dataloader: torch.utils.data.DataLoader,
    patients: list,
    optimizer: torch.optim.Optimizer,
    loss_fn: torch.nn.Module,
    val_data: tuple,
):
    best_loss = [np.inf] * len(patients)
    val_history, train_history = [], []
    saved_models = [None] * len(patients)
    patients_stopped_epoch = [np.inf] * len(patients)

    # -------------------- Train  Loop----------------------------
    patient_counter = [0] * len(patients)
    for epoch in range(epochs):  # iterate over epoch
        # -------------------- 1. Training on each epoch ----------------------------
        accumulated_loss, accumulated_accuracy = (
            0,
            0,
        )  # monitor loss and metrics during training
        for step, batch_data in enumerate(train_dataloader):  # iterate over batch
            loss, accuracy = training_step(
                model, batch_data, optimizer, loss_fn
            )  # train model using a single batch
            accumulated_loss = (step * accumulated_loss + loss) / (step + 1)
            accumulated_accuracy = (step * accumulated_accuracy + accuracy) / (step + 1)

        # store the loss and the metrics at the end of each epoch
        train_history += [
            {"loss": accumulated_loss, "accuracy": accumulated_accuracy, "epoch": epoch}
        ]

        # -------------------- 2. Monitor Error on Validation set ----------------------------
        val_loss, val_accuracy = evaluation_step(model, val_data, loss_fn)
        val_history += [{"loss": val_loss, "accuracy": val_accuracy, "epoch": epoch}]
        if epoch % 10 == 0:
            print(
                f"Epoch {epoch}/{epochs}:  loss:{accumulated_loss:.3f}, accuracy-:{accumulated_accuracy:.3f}, val_loss:{val_loss:.3f}, val_accuracy->{val_accuracy:.3f}"
            )

        # -------------------- 3. Early Stopping ----------------------------
        for model_id, patient in enumerate(patients):
            if epoch < patients_stopped_epoch[model_id]:
                if val_loss < best_loss[model_id]:
                    best_loss[model_id] = val_loss
                    patient_counter[model_id] = 0
                else:
                    patient_counter[model_id] += 1

                if patient_counter[model_id] >= patient:
                    print(
                        f"Early stopping at epoch {epoch} with patient {patient} for model {model_id}"
                    )
                    saved_models[model_id] = model.state_dict()
                    patients_stopped_epoch[model_id] = epoch

        # -------------------- 4. Stop training if all models have stopped ----------------------------
        if all(
            [
                patient_counter[model_id] >= patient
                for model_id, patient in enumerate(patients)
            ]
        ):
            print("All models have stopped")
            break

    return (
        pd.DataFrame(val_history),
        pd.DataFrame(train_history),
        [model.load_state_dict(saved_model) for saved_model in saved_models],
        patients_stopped_epoch,
    )

# %%
patients = [5, 100]

# %%
(
    val_history_df_early_stopping,
    train_history_df_early_stopping,
    saved_models,
    patients_stopped_epoch,
) = train_with_early_stopping(
    model,
    epochs,
    train_dataloader,
    patients,
    optimizer,
    loss_fn,
    (val_x_tensor, val_y_tensor),
)
# Out:
# Epoch 0/400:  loss:0.466, accuracy-:0.783, val_loss:0.379, val_accuracy->0.840
# Epoch 10/400:  loss:0.334, accuracy-:0.841, val_loss:0.325, val_accuracy->0.849
# Epoch 20/400:  loss:0.327, accuracy-:0.845, val_loss:0.321, val_accuracy->0.856
# Epoch 30/400:  loss:0.325, accuracy-:0.848, val_loss:0.321, val_accuracy->0.851
# Epoch 40/400:  loss:0.321, accuracy-:0.850, val_loss:0.319, val_accuracy->0.854
# Epoch 50/400:  loss:0.317, accuracy-:0.851, val_loss:0.318, val_accuracy->0.856
# Early stopping at epoch 54 with patient 5 for model 0
# Epoch 60/400:  loss:0.313, accuracy-:0.852, val_loss:0.349, val_accuracy->0.854
# Epoch 70/400:  loss:0.310, accuracy-:0.852, val_loss:0.349, val_accuracy->0.855
# Epoch 80/400:  loss:0.307, accuracy-:0.855, val_loss:0.320, val_accuracy->0.854
# Epoch 90/400:  loss:0.305, accuracy-:0.855, val_loss:0.317, val_accuracy->0.853
# Epoch 100/400:  loss:0.302, accuracy-:0.856, val_loss:0.356, val_accuracy->0.849
# Epoch 110/400:  loss:0.299, accuracy-:0.859, val_loss:0.348, val_accuracy->0.853
# Epoch 120/400:  loss:0.296, accuracy-:0.860, val_loss:0.353, val_accuracy->0.854
# Epoch 130/400:  loss:0.294, accuracy-:0.860, val_loss:0.322, val_accuracy->0.851
# Epoch 140/400:  loss:0.292, accuracy-:0.862, val_loss:0.353, val_accuracy->0.852
# Early stopping at epoch 149 with patient 100 for model 1
# All models have stopped

# %%
for model_id, patient in enumerate(patients_stopped_epoch):
    plot_accuracy(train_history_df_big[:patient], val_history_df_big[:patient], patient)
    plot_loss(train_history_df_big[:patient], val_history_df_big[:patient], patient)

# %% [markdown]
# # B. Reduce the Size of the Network
#
# The capacity (total number of parameters) of the model affects the training process. If the parameters are too numerous compared to the difficulty of the underlying problem, it's very easy to overfit.
#
# To address this issue, reduce the total number of parameters in the model by decreasing the number of units in each layer, and then comment on the results.
#
# **Steps:**
# 1. Reduce the size of the network by lowering the number of units. You can use 60 units for the first layer and 20 units for the second one.
# 2. Train your model without early stopping.
# 3. Compare the learning curve of this model with the learning curve of the larger model we trained without early stopping (used in section Learning Curves and Overfitting).

# %% [markdown]
# # Solution

# %%
model = NeuralNetwork(num_input_features=13, layer1_units=60, layer2_units=20)
lr = 0.02
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
loss_fn = torch.nn.BCELoss() # binary cross entropy

summary(model, input_size=[[13]])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 60]             840
#               ReLU-2                   [-1, 60]               0
#             Linear-3                   [-1, 20]           1,220
#               ReLU-4                   [-1, 20]               0
#             Linear-5                    [-1, 1]              21
#            Sigmoid-6                    [-1, 1]               0
# ================================================================
# Total params: 2,081
# Trainable params: 2,081
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------

# %%
epochs = 200   
(
    val_history_df_small,
    train_history_df_small,
) = train(
    model,
    epochs,
    train_dataloader,
    optimizer,
    loss_fn,
    (val_x_tensor, val_y_tensor),
)
# Out:
# Epoch 0/200:  loss:0.507, accuracy-:0.755, val_loss:0.425, val_accuracy->0.785
# Epoch 10/200:  loss:0.337, accuracy-:0.841, val_loss:0.326, val_accuracy->0.851
# Epoch 20/200:  loss:0.331, accuracy-:0.845, val_loss:0.321, val_accuracy->0.853
# Epoch 30/200:  loss:0.327, accuracy-:0.846, val_loss:0.319, val_accuracy->0.857
# Epoch 40/200:  loss:0.324, accuracy-:0.847, val_loss:0.319, val_accuracy->0.857
# Epoch 50/200:  loss:0.321, accuracy-:0.849, val_loss:0.318, val_accuracy->0.854
# Epoch 60/200:  loss:0.318, accuracy-:0.849, val_loss:0.317, val_accuracy->0.853
# Epoch 70/200:  loss:0.316, accuracy-:0.850, val_loss:0.318, val_accuracy->0.855
# Epoch 80/200:  loss:0.314, accuracy-:0.851, val_loss:0.317, val_accuracy->0.850
# Epoch 90/200:  loss:0.312, accuracy-:0.852, val_loss:0.319, val_accuracy->0.854
# Epoch 100/200:  loss:0.310, accuracy-:0.851, val_loss:0.318, val_accuracy->0.854
# Epoch 110/200:  loss:0.309, accuracy-:0.852, val_loss:0.319, val_accuracy->0.852
# Epoch 120/200:  loss:0.307, accuracy-:0.854, val_loss:0.319, val_accuracy->0.854
# Epoch 130/200:  loss:0.306, accuracy-:0.854, val_loss:0.320, val_accuracy->0.853
# Epoch 140/200:  loss:0.304, accuracy-:0.854, val_loss:0.323, val_accuracy->0.853
# Epoch 150/200:  loss:0.304, accuracy-:0.854, val_loss:0.319, val_accuracy->0.853
# Epoch 160/200:  loss:0.303, accuracy-:0.855, val_loss:0.318, val_accuracy->0.857
# Epoch 170/200:  loss:0.302, accuracy-:0.853, val_loss:0.323, val_accuracy->0.854
# Epoch 180/200:  loss:0.301, accuracy-:0.852, val_loss:0.319, val_accuracy->0.851
# Epoch 190/200:  loss:0.300, accuracy-:0.855, val_loss:0.324, val_accuracy->0.854

# %%
plot_accuracy(train_history_df_small, val_history_df_small, epochs)
plot_loss(train_history_df_small, val_history_df_small, epochs)

# %%
plot_accuracy(train_history_df_big, val_history_df_big, epochs)
plot_loss(train_history_df_big, val_history_df_big, epochs)

# %% [markdown]
# # C. Weight Regularization
#
# Weight Regularization is another very famous technique to reduce overfitting.
# The concept of regularization is to add a constraint in the loss function to keep the weights of the model small.
#
# To get the intuition, weights regularization discourages the model from fitting the training data too closely and forces it to focus on the most important features. By constraining the model's weights, it can generalize better to new data because it's less likely to memorize the training examples and is more likely to capture underlying patterns and relationships in the data.
#
# A very famous and easy regularization is the L2-regularization where we modify the loss function as follows:
#
# $$ \text{Total Loss} = \mathbb{E}_{x,y \sim P_{data}} \left[ loss(f_w(x),y) \right] + \lambda \sum_{j=1}^{p} w_j^2 $$
#
# Where $\lambda$ is a scaling paramter, $loss$ in the loss function, $w$ the parameters of the model. Finally, $p$ indicates the set of different parameters
#
# In pytorch is very easy to apply L2-regularization. You can do that using the weight_decay ($\lambda$) parameter of the optimizer class.

# %% [markdown]
# ```python
# torch.optim.SGD(model.parameters(), lr=lr, weight_decay=λ)

# %% [markdown]
# **Steps :**
# 1) Use $\lambda = 0.01$ and train your model using L2 regularization, as explained begore.
# Use the model architeture with the more paramter and dont aply early stoping to see the effect.
# 3) Compare with the initial training without early stoping (used in section Learning Curves and Overfitting) and comment on the results.

# %% [markdown]
# # Solution

# %%
model = NeuralNetwork(num_input_features=13)
lr = 0.02
l = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=lr, weight_decay=l)
loss_fn = torch.nn.BCELoss() # binary cross entropy

summary(model, input_size=[[13]])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 200]           2,800
#               ReLU-2                  [-1, 200]               0
#             Linear-3                  [-1, 100]          20,100
#               ReLU-4                  [-1, 100]               0
#             Linear-5                    [-1, 1]             101
#            Sigmoid-6                    [-1, 1]               0
# ================================================================
# Total params: 23,001
# Trainable params: 23,001
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.09
# Estimated Total Size (MB): 0.09
# ----------------------------------------------------------------

# %%
epochs = 200
train_history_df_big_l2, val_history_df_big_l2 = train(model, epochs, train_dataloader, optimizer, loss_fn, (val_x_tensor, val_y_tensor))
# Out:
# Epoch 0/200:  loss:0.468, accuracy-:0.783, val_loss:0.383, val_accuracy->0.839
# Epoch 10/200:  loss:0.343, accuracy-:0.838, val_loss:0.330, val_accuracy->0.849
# Epoch 20/200:  loss:0.339, accuracy-:0.841, val_loss:0.329, val_accuracy->0.850
# Epoch 30/200:  loss:0.339, accuracy-:0.840, val_loss:0.326, val_accuracy->0.853
# Epoch 40/200:  loss:0.338, accuracy-:0.839, val_loss:0.327, val_accuracy->0.852
# Epoch 50/200:  loss:0.338, accuracy-:0.840, val_loss:0.326, val_accuracy->0.852
# Epoch 60/200:  loss:0.338, accuracy-:0.839, val_loss:0.328, val_accuracy->0.855
# Epoch 70/200:  loss:0.338, accuracy-:0.840, val_loss:0.326, val_accuracy->0.852
# Epoch 80/200:  loss:0.338, accuracy-:0.840, val_loss:0.326, val_accuracy->0.853
# Epoch 90/200:  loss:0.338, accuracy-:0.841, val_loss:0.327, val_accuracy->0.852
# Epoch 100/200:  loss:0.338, accuracy-:0.840, val_loss:0.327, val_accuracy->0.853
# Epoch 110/200:  loss:0.338, accuracy-:0.839, val_loss:0.326, val_accuracy->0.853
# Epoch 120/200:  loss:0.338, accuracy-:0.840, val_loss:0.327, val_accuracy->0.852
# Epoch 130/200:  loss:0.338, accuracy-:0.840, val_loss:0.325, val_accuracy->0.851
# Epoch 140/200:  loss:0.338, accuracy-:0.840, val_loss:0.328, val_accuracy->0.852
# Epoch 150/200:  loss:0.338, accuracy-:0.840, val_loss:0.328, val_accuracy->0.851
# Epoch 160/200:  loss:0.338, accuracy-:0.840, val_loss:0.327, val_accuracy->0.852
# Epoch 170/200:  loss:0.338, accuracy-:0.840, val_loss:0.328, val_accuracy->0.852
# Epoch 180/200:  loss:0.338, accuracy-:0.840, val_loss:0.328, val_accuracy->0.852
# Epoch 190/200:  loss:0.338, accuracy-:0.840, val_loss:0.327, val_accuracy->0.852

# %%
plot_accuracy(train_history_df_big_l2, val_history_df_big_l2, epochs)
plot_loss(train_history_df_big_l2, val_history_df_big_l2, epochs)

# %%
plot_accuracy(train_history_df_big, val_history_df_big, epochs)
plot_loss(train_history_df_big, val_history_df_big, epochs)

# %% [markdown]
# ### Comment on the results
# On the original training without L2 regularization we can see that the training loss separates from the validation loss. This shows that the model seems to not be able to learn the patterns of the data and overfit the training data. In contrast, when we use L2 regularization we can see that the training loss and the validation loss are very close. This shows that the model is able to learn the patterns of the data and generalize well to the validation data.
